# %%
import pandas as pd
from pandas.tseries.offsets import MonthEnd
import numpy as np
from beakerx import *
from beakerx.object import beakerx
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sci
from copy import copy
from IPython.display import HTML
from multiprocessing import Pool, cpu_count

# %% [markdown]
# # Import the data

# %%
crsp_raw = pd.read_csv('../Data/crsp.txt', sep = '\t', low_memory = False, nrows = 10000)

# %%
compustat_raw = pd.read_csv('./Data/compustat-merged.txt', sep = '\t', low_memory = False, nrows = 10000)

# %%
def clean_data(df, type_dict):
    print('Cleaning date variables:')
    for v in type_dict['date_vars']:
        print(v)
        df[v] = pd.to_datetime(df[v], format = '%Y/%m/%d', errors = 'coerce', cache = True).dt.tz_localize(None) + MonthEnd(0)
        
    print('Cleaning numeric variables:')
    for v in type_dict['float_vars']:
        print(v)
        df[v] = pd.to_numeric(df[v], errors = 'coerce')
    
    print('Cleaning integer variables:')
    for v in type_dict['int_vars']:
        print(v)
        df[v] = pd.to_numeric(df[v], downcast = 'signed', errors = 'coerce')
        
    print('Final data types:')
    print(df.dtypes)
    
    return df

# %% [markdown]
# ## Cleaning Up CRSP

# %%
crsp_datatypes = {'date_vars': ['date'],
                 'float_vars': ['BIDLO', 'ASKHI', 'PRC', 'RET', 'DLRET', 'BID', 'ASK', 'RETX', 'CFACPR', 'CFACSHR'],
                 'int_vars': ['PERMNO', 'PERMCO', 'HSICCD', 'CUSIP', 'SHROUT', 'VOL']}
crsp = clean_data(copy(crsp_raw), crsp_datatypes)
# Out:
# Cleaning date variables:
# date
# Cleaning numeric variables:
# BIDLO
# ASKHI
# PRC
# RET
# DLRET
# BID
# ASK
# RETX
# CFACPR
# CFACSHR
# Cleaning integer variables:
# PERMNO
# PERMCO
# HSICCD
# CUSIP
# SHROUT
# VOL
# Final data types:
# PERMNO              int32
# date       datetime64[ns]
# TICKER             object
# COMNAM             object
# SHRCLS             object
# PERMCO               int8
# HSICCD              int16
# CUSIP             float64
# DLSTCD            float64
# NWPERM            float64
# DLPRC             float64
# DLRET             float64
# BIDLO             float64
# ASKHI             float64
# PRC               float64
# VOL               float64
# RET               float64
# BID               float64
# ASK               float64
# SHROUT            float64
# CFACPR            float64
# CFACSHR           float64
# RETX              float64
# dtype: object

# %%
# Choose the right variables
crsp_names = {'RET': 'Return', 
              'SHROUT': 'Shares Outstanding on Trading Day', 
              'COMNAM': 'Company Name',
              'TICKER': 'Ticker',
              'date': 'datadate', 
              'PERMNO': 'Permno', 
              'PERMCO': 'Permco',
              'PRC': 'Price with Flag',
              'BID': 'Bid',
              'ASK': 'Ask',
              'VOL': 'Volume on Trading Day',
              'SHRCLS': 'Share Class',
              'CFACPR': 'Price Adjustment Factor',
              'CFACSHR': 'Share Adjustment Factor'}

crsp = crsp.rename(index = str, columns = crsp_names)
crsp = crsp[list(crsp_names.values())]

# %%
# Make a few more useful variables
crsp['Imputed Price'] = (crsp['Price with Flag'] < 0)
crsp['Price on Trading Day'] = np.abs(crsp['Price with Flag'])
crsp['Price'] = crsp['Price on Trading Day'] / crsp['Price Adjustment Factor']
crsp['Shares Outstanding'] = crsp['Shares Outstanding on Trading Day'] * crsp['Share Adjustment Factor']
crsp['Volume'] = crsp['Volume on Trading Day'] * crsp['Share Adjustment Factor']
crsp['Market Cap (Billions, CRSP)'] = crsp['Shares Outstanding'] * crsp['Price'] / 1e6

# %%
# Drop a few variables
crsp = crsp.drop(['Price on Trading Day', 'Shares Outstanding on Trading Day', 'Volume on Trading Day'], axis = 1)

# %%
crsp.head()

# %%
# Check for unique identifier

def check_unique(dataframe, identifier_list):
    unique_identifier = dataframe.groupby(by = identifier_list).count()
    return unique_identifier.shape[0] == dataframe.shape[0]

print(check_unique(crsp, ['Permco', 'datadate']))
# Out:
# False

# %%
crsp = crsp.reset_index().set_index(['Permco', 'datadate'])

# %%
AGG_VAR_TYPES = {'First': ['Company Name', 'Ticker', 'Price', 'Bid', 'Ask'],
             'Add': ['Market Cap (Billions, CRSP)'],
             'Weighted Sum': ['Volume', 'Return']}
ALL_CRSP_VAR = [item for sublist in AGG_VAR_TYPES.values() for item in sublist]

def agg_share_classes(company_on_date):
    
    if ('Loop Number' in company_on_date.columns) and company_on_date['Loop Number'].values[0] % 1000 == 0:
        print(company_on_date.index[0])
    
    # If only one share class
    if company_on_date.shape[1] <= 1:
        return company_on_date[ALL_CRSP_VAR]
    
    print('Going for remaing cases')
    # Then for the remainign cases
    company_on_date['Market Cap (Billions, CRSP)'].fillna(0)
    largest_market_cap = company_on_date['Market Cap (Billions, CRSP)'].max()
    largest_class = (company_on_date['Market Cap (Billions, CRSP)'] == largest_market_cap)
    
    # If there is no valid market cap, just pick the first record arbitrarily
    if largest_market_cap > 0:
        find_valid = np.where(largest_class)[0]
        if find_valid.shape[0] > 1:
            largest_class[find_valid[0] + 1:] = False
            largest_class[find_valid[0]] = True
    else:
        largest_class[0] = True
        largest_class[1:] = False
    
    print(largest_class)
    assert(np.where(largest_class)[0].shape[0] == 1)
        
    new_frame = {}
    for v in AGG_VAR_TYPES['First']:
        new_frame[v] = company_on_date.loc[largest_class, v]

    for v in AGG_VAR_TYPES['Add']:
        new_frame[v] = company_on_date[v].fillna(0).sum()

    for v in AGG_VAR_TYPES['Weighted Sum']:
        valid = ~company_on_date[v].isnull()
        denominator = company_on_date.loc[valid, 'Market Cap (Billions, CRSP)'].sum()
        
        if denominator > 0:
            new_frame[v] = (company_on_date.loc[valid, v] * company_on_date.loc[valid, 'Market Cap (Billions, CRSP)']).sum() / denominator
        else:
            new_frame[v] = company_on_date[v][0]
        
    return pd.DataFrame.from_dict(new_frame)

# %%
# First, pull every permco-date that isn't paired
crsp_counts = crsp['Permno'].groupby(by = ['Permco', 'datadate']).count()
crsp_counts.name = 'Count'
crsp_counts = crsp_counts[crsp_counts > 1]
crsp_counts = crsp_counts.to_frame()

# %%
crsp_merge = crsp_counts.join(crsp, how = 'outer')

# %%
problem_children = crsp_merge.loc[~pd.isnull(crsp_merge['Count']), ALL_CRSP_VAR]
good_children = crsp_merge.loc[pd.isnull(crsp_merge['Count']), ALL_CRSP_VAR]

# %%
problem_children['Loop Number'] = list(range(problem_children.shape[0]))

# %%
merged_problems = problem_children.groupby(['Permco', 'datadate']).apply(agg_share_classes)
# Out:
# (32, Timestamp('1983-06-30 00:00:00'))
# Going for remaing cases
# Permco  datadate
# 32      1983-06-30     True
#         1983-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-07-31    False
#         1983-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-08-31     True
#         1983-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-09-30     True
#         1983-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-10-31     True
#         1983-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-11-30     True
#         1983-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1983-12-31    False
#         1983-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-01-31     True
#         1984-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-02-29    False
#         1984-02-29     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-03-31    False
#         1984-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-04-30     True
#         1984-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-05-31     True
#         1984-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-06-30     True
#         1984-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-07-31     True
#         1984-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-08-31     True
#         1984-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-09-30     True
#         1984-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-10-31     True
#         1984-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-11-30     True
#         1984-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1984-12-31     True
#         1984-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-01-31     True
#         1985-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-02-28     True
#         1985-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-03-31     True
#         1985-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-04-30     True
#         1985-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-05-31     True
#         1985-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-06-30     True
#         1985-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-07-31     True
#         1985-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-08-31     True
#         1985-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-09-30     True
#         1985-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-10-31     True
#         1985-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-11-30     True
#         1985-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1985-12-31    False
#         1985-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-01-31    False
#         1986-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-02-28    False
#         1986-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-03-31    False
#         1986-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-04-30    False
#         1986-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-05-31    False
#         1986-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-06-30    False
#         1986-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-07-31    False
#         1986-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-08-31    False
#         1986-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-09-30    False
#         1986-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-10-31    False
#         1986-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-11-30     True
#         1986-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1986-12-31     True
#         1986-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-01-31    False
#         1987-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-02-28     True
#         1987-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-03-31     True
#         1987-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-04-30    False
#         1987-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-05-31    False
#         1987-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-06-30    False
#         1987-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-07-31    False
#         1987-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-08-31    False
#         1987-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-09-30    False
#         1987-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-10-31    False
#         1987-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-11-30    False
#         1987-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1987-12-31     True
#         1987-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-01-31     True
#         1988-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-02-29    False
#         1988-02-29     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-03-31     True
#         1988-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-04-30     True
#         1988-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-05-31     True
#         1988-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-06-30    False
#         1988-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-07-31    False
#         1988-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-08-31     True
#         1988-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-09-30    False
#         1988-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-10-31    False
#         1988-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-11-30    False
#         1988-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1988-12-31    False
#         1988-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-01-31     True
#         1989-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-02-28    False
#         1989-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-03-31    False
#         1989-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-04-30    False
#         1989-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-05-31    False
#         1989-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-06-30    False
#         1989-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-07-31    False
#         1989-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-08-31    False
#         1989-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-09-30    False
#         1989-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-10-31    False
#         1989-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-11-30    False
#         1989-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1989-12-31    False
#         1989-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-01-31    False
#         1990-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-02-28    False
#         1990-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-03-31    False
#         1990-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-04-30    False
#         1990-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-05-31    False
#         1990-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-06-30    False
#         1990-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-07-31    False
#         1990-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-08-31    False
#         1990-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-09-30    False
#         1990-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-10-31    False
#         1990-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-11-30    False
#         1990-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1990-12-31    False
#         1990-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-01-31    False
#         1991-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-02-28    False
#         1991-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-03-31    False
#         1991-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-04-30     True
#         1991-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-05-31     True
#         1991-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-06-30    False
#         1991-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-07-31    False
#         1991-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-08-31    False
#         1991-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-09-30    False
#         1991-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-10-31    False
#         1991-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-11-30    False
#         1991-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1991-12-31    False
#         1991-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-01-31    False
#         1992-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-02-29     True
#         1992-02-29    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-03-31    False
#         1992-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-04-30    False
#         1992-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-05-31    False
#         1992-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-06-30    False
#         1992-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-07-31     True
#         1992-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-08-31    False
#         1992-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-09-30    False
#         1992-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-10-31    False
#         1992-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-11-30    False
#         1992-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1992-12-31    False
#         1992-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-01-31     True
#         1993-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-02-28    False
#         1993-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-03-31    False
#         1993-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-04-30     True
#         1993-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-05-31    False
#         1993-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-06-30    False
#         1993-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-07-31    False
#         1993-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-08-31    False
#         1993-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-09-30    False
#         1993-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-10-31    False
#         1993-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-11-30    False
#         1993-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1993-12-31    False
#         1993-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-01-31    False
#         1994-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-02-28    False
#         1994-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-03-31    False
#         1994-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-04-30    False
#         1994-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-05-31    False
#         1994-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-06-30    False
#         1994-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-07-31    False
#         1994-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-08-31    False
#         1994-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-09-30    False
#         1994-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-10-31    False
#         1994-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-11-30    False
#         1994-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 32      1994-12-31     True
#         1994-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-01-31     True
#         2005-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-02-28     True
#         2005-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-03-31     True
#         2005-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-04-30     True
#         2005-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-05-31     True
#         2005-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-06-30     True
#         2005-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-07-31     True
#         2005-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-08-31     True
#         2005-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-09-30     True
#         2005-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-10-31     True
#         2005-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-11-30     True
#         2005-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2005-12-31     True
#         2005-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-01-31     True
#         2006-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-02-28     True
#         2006-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-03-31     True
#         2006-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-04-30     True
#         2006-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-05-31     True
#         2006-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-06-30     True
#         2006-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-07-31     True
#         2006-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-08-31     True
#         2006-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-09-30     True
#         2006-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-10-31     True
#         2006-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-11-30     True
#         2006-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2006-12-31     True
#         2006-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-01-31     True
#         2007-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-02-28     True
#         2007-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-03-31     True
#         2007-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-04-30     True
#         2007-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-05-31     True
#         2007-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-06-30     True
#         2007-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-07-31     True
#         2007-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-08-31     True
#         2007-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-09-30     True
#         2007-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-10-31     True
#         2007-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-11-30     True
#         2007-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2007-12-31     True
#         2007-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-01-31     True
#         2008-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-02-29     True
#         2008-02-29    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-03-31     True
#         2008-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-04-30     True
#         2008-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-05-31     True
#         2008-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-06-30     True
#         2008-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-07-31     True
#         2008-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-08-31     True
#         2008-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-09-30     True
#         2008-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-10-31     True
#         2008-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-11-30     True
#         2008-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2008-12-31     True
#         2008-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-01-31     True
#         2009-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-02-28     True
#         2009-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-03-31     True
#         2009-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-04-30     True
#         2009-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-05-31     True
#         2009-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-06-30     True
#         2009-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-07-31     True
#         2009-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-08-31     True
#         2009-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-09-30     True
#         2009-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-10-31     True
#         2009-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-11-30     True
#         2009-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2009-12-31     True
#         2009-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-01-31     True
#         2010-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-02-28     True
#         2010-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-03-31     True
#         2010-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-04-30     True
#         2010-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-05-31     True
#         2010-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-06-30     True
#         2010-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-07-31     True
#         2010-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-08-31     True
#         2010-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-09-30     True
#         2010-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-10-31     True
#         2010-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-11-30     True
#         2010-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2010-12-31     True
#         2010-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-01-31     True
#         2011-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-02-28     True
#         2011-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-03-31     True
#         2011-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-04-30     True
#         2011-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-05-31     True
#         2011-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-06-30     True
#         2011-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-07-31     True
#         2011-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-08-31     True
#         2011-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-09-30     True
#         2011-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-10-31     True
#         2011-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-11-30     True
#         2011-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2011-12-31     True
#         2011-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-01-31     True
#         2012-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-02-29     True
#         2012-02-29    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-03-31     True
#         2012-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-04-30     True
#         2012-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-05-31     True
#         2012-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-06-30     True
#         2012-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-07-31     True
#         2012-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-08-31     True
#         2012-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-09-30     True
#         2012-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-10-31     True
#         2012-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-11-30     True
#         2012-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2012-12-31     True
#         2012-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-01-31     True
#         2013-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-02-28     True
#         2013-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-03-31     True
#         2013-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-04-30     True
#         2013-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-05-31     True
#         2013-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-06-30     True
#         2013-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-07-31     True
#         2013-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-08-31     True
#         2013-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-09-30     True
#         2013-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-10-31     True
#         2013-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-11-30     True
#         2013-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2013-12-31     True
#         2013-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-01-31     True
#         2014-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-02-28     True
#         2014-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-03-31     True
#         2014-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-04-30     True
#         2014-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-05-31     True
#         2014-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-06-30     True
#         2014-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-07-31     True
#         2014-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-08-31     True
#         2014-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-09-30     True
#         2014-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-10-31     True
#         2014-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-11-30     True
#         2014-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2014-12-31     True
#         2014-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-01-31     True
#         2015-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-02-28     True
#         2015-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-03-31     True
#         2015-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-04-30     True
#         2015-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-05-31     True
#         2015-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-06-30     True
#         2015-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-07-31     True
#         2015-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-08-31     True
#         2015-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-09-30     True
#         2015-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-10-31     True
#         2015-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-11-30     True
#         2015-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2015-12-31     True
#         2015-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-01-31     True
#         2016-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-02-29     True
#         2016-02-29    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-03-31     True
#         2016-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-04-30     True
#         2016-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-05-31     True
#         2016-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-06-30     True
#         2016-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-07-31     True
#         2016-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-08-31     True
#         2016-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-09-30     True
#         2016-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-10-31     True
#         2016-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-11-30     True
#         2016-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2016-12-31     True
#         2016-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-01-31     True
#         2017-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-02-28     True
#         2017-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-03-31     True
#         2017-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-04-30     True
#         2017-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-05-31     True
#         2017-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-06-30     True
#         2017-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-07-31     True
#         2017-07-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-08-31     True
#         2017-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-09-30     True
#         2017-09-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-10-31     True
#         2017-10-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-11-30     True
#         2017-11-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2017-12-31     True
#         2017-12-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-01-31     True
#         2018-01-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-02-28     True
#         2018-02-28    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-03-31     True
#         2018-03-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-04-30     True
#         2018-04-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-05-31     True
#         2018-05-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 33      2018-06-30     True
#         2018-06-30    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1987-08-31     True
#         1987-08-31    False
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1987-09-30    False
#         1987-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1987-10-31    False
#         1987-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1987-11-30    False
#         1987-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1987-12-31    False
#         1987-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-01-31    False
#         1988-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-02-29    False
#         1988-02-29     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-03-31    False
#         1988-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-04-30    False
#         1988-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-05-31    False
#         1988-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-06-30    False
#         1988-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-07-31    False
#         1988-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-08-31    False
#         1988-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-09-30    False
#         1988-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-10-31    False
#         1988-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-11-30    False
#         1988-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1988-12-31    False
#         1988-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-01-31    False
#         1989-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-02-28    False
#         1989-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-03-31    False
#         1989-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-04-30    False
#         1989-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-05-31    False
#         1989-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-06-30    False
#         1989-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-07-31    False
#         1989-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-08-31    False
#         1989-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-09-30    False
#         1989-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-10-31    False
#         1989-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-11-30    False
#         1989-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1989-12-31    False
#         1989-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-01-31    False
#         1990-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-02-28    False
#         1990-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-03-31    False
#         1990-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-04-30    False
#         1990-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-05-31    False
#         1990-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-06-30    False
#         1990-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-07-31    False
#         1990-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-08-31    False
#         1990-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-09-30    False
#         1990-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-10-31    False
#         1990-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-11-30    False
#         1990-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1990-12-31    False
#         1990-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-01-31    False
#         1991-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-02-28    False
#         1991-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-03-31    False
#         1991-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-04-30    False
#         1991-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-05-31    False
#         1991-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-06-30    False
#         1991-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-07-31    False
#         1991-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-08-31    False
#         1991-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-09-30    False
#         1991-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-10-31    False
#         1991-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-11-30    False
#         1991-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1991-12-31    False
#         1991-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-01-31    False
#         1992-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-02-29    False
#         1992-02-29     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-03-31    False
#         1992-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-04-30    False
#         1992-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-05-31    False
#         1992-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-06-30    False
#         1992-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-07-31    False
#         1992-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-08-31    False
#         1992-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-09-30    False
#         1992-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-10-31    False
#         1992-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-11-30    False
#         1992-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1992-12-31    False
#         1992-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-01-31    False
#         1993-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-02-28    False
#         1993-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-03-31    False
#         1993-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-04-30    False
#         1993-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-05-31    False
#         1993-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-06-30    False
#         1993-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-07-31    False
#         1993-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-08-31    False
#         1993-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-09-30    False
#         1993-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-10-31    False
#         1993-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-11-30    False
#         1993-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1993-12-31    False
#         1993-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-01-31    False
#         1994-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-02-28    False
#         1994-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-03-31    False
#         1994-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-04-30    False
#         1994-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-05-31    False
#         1994-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-06-30    False
#         1994-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-07-31    False
#         1994-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-08-31    False
#         1994-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-09-30    False
#         1994-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-10-31    False
#         1994-10-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-11-30    False
#         1994-11-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1994-12-31    False
#         1994-12-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-01-31    False
#         1995-01-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-02-28    False
#         1995-02-28     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-03-31    False
#         1995-03-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-04-30    False
#         1995-04-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-05-31    False
#         1995-05-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-06-30    False
#         1995-06-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-07-31    False
#         1995-07-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-08-31    False
#         1995-08-31     True
# Name: Market Cap (Billions, CRSP), dtype: bool
# Going for remaing cases
# Permco  datadate
# 47      1995-09-30    False
#         1995-09-30     True
# Name: Market Cap (Billions, CRSP), dtype: bool

# %%
crsp_merge = pd.concat([good_children[ALL_CRSP_VAR], merged_problems[ALL_CRSP_VAR]])

# %%
apple = crsp.xs(7, level = 'Permco', drop_level = False)

# %%
apple = apple.loc[~pd.isnull(apple['Return'])]
times = apple.index.get_level_values(1)

# %%
x = times.shift(1, freq = 'M') - times

# %%
x.max().total_seconds() < 32 * 24 * 60 * 60
# Out:
# True

# %%
def continuous_returns(company_dataframe):
    """
    Detects if a company has continuous return data. Returns "True" if the returns are continuous. False otherwise
    :param company_dataframe -- a dataframe from a groupby object, indexed on Permco
    :returns True or False, depending on whether the return sequence is continuous
    """
    print(company_dataframe.head())
    times = company_dataframe.index.get_level_values(1)
    diffs = times.shift(1, freq = 'M') - times
    return (diffs.max().total_seconds() < 32 * 24 * 60 * 60)

# %%
test_returns = crsp_merge.iloc[0:1000, :]

# %%
test_returns.groupby(by = ['Permco']).apply(continuous_returns)
# Out:
#                                    Company Name Ticker   Price  Bid  Ask  \
# Permco datadate
# 2      1972-11-30                           NaN    NaN     NaN  NaN  NaN
#        1972-12-31  ANGLO AMERICAN GOLD INVT LTD  AAGIY  2.3000  NaN  NaN
#        1973-01-31  ANGLO AMERICAN GOLD INVT LTD  AAGIY  2.7125  NaN  NaN
#        1973-02-28  ANGLO AMERICAN GOLD INVT LTD  AAGIY  3.0625  NaN  NaN
#        1973-03-31  ANGLO AMERICAN GOLD INVT LTD  AAGIY  3.5125  NaN  NaN
#
#                    Market Cap (Billions, CRSP)  Volume    Return
# Permco datadate
# 2      1972-11-30                          NaN     NaN       NaN
#        1972-12-31                     0.504896     NaN       NaN
#        1973-01-31                     0.595448     NaN  0.179348
#        1973-02-28                     0.672280     NaN  0.157272
#        1973-03-31                     0.771064     NaN  0.146939
#                         Company Name Ticker   Price  Bid  Ask  \
# Permco datadate
# 3      1976-12-31                NaN    NaN     NaN  NaN  NaN
#        1977-01-31  CARIBBEAN FIN INC   CBNF  4.5000  NaN  NaN
#        1977-02-28  CARIBBEAN FIN INC   CBNF  4.8750  NaN  NaN
#        1977-03-31  CARIBBEAN FIN INC   CBNF  4.2500  NaN  NaN
#        1977-04-30  CARIBBEAN FIN INC   CBNF  4.5625  NaN  NaN
#
#                    Market Cap (Billions, CRSP)  Volume    Return
# Permco datadate
# 3      1976-12-31                          NaN     NaN       NaN
#        1977-01-31                     0.006412     NaN       NaN
#        1977-02-28                     0.006947     NaN  0.083333
#        1977-03-31                     0.006056     NaN -0.128205
#        1977-04-30                     0.006502     NaN  0.073529
#                                 Company Name Ticker    Price  Bid  Ask  \
# Permco datadate
# 4      1972-11-30                        NaN    NaN      NaN  NaN  NaN
#        1972-12-31  ALEXANDER & ALEXANDER INC   AALX  16.3125  NaN  NaN
#        1973-01-31  ALEXANDER & ALEXANDER INC   AALX  11.8125  NaN  NaN
#        1973-02-28  ALEXANDER & ALEXANDER INC   AALX  10.1875  NaN  NaN
#        1973-03-31  ALEXANDER & ALEXANDER INC   AALX   9.5625  NaN  NaN
#
#                    Market Cap (Billions, CRSP)  Volume    Return
# Permco datadate
# 4      1972-11-30                          NaN     NaN       NaN
#        1972-12-31                     0.146388     NaN       NaN
#        1973-01-31                     0.106005     NaN -0.275862
#        1973-02-28                     0.091423     NaN -0.132910
#        1973-03-31                     0.085814     NaN -0.061350
#                              Company Name Ticker     Price  Bid  Ask  \
# Permco datadate
# 5      1972-11-30                     NaN    NaN       NaN  NaN  NaN
#        1972-12-31  ATLANTIC AMERICAN CORP   AAME  0.545462  NaN  NaN
#        1973-01-31  ATLANTIC AMERICAN CORP   AAME  0.569178  NaN  NaN
#        1973-02-28  ATLANTIC AMERICAN CORP   AAME  0.498031  NaN  NaN
#        1973-03-31  ATLANTIC AMERICAN CORP   AAME  0.379452  NaN  NaN
#
#                    Market Cap (Billions, CRSP)  Volume    Return
# Permco datadate
# 5      1972-11-30                          NaN     NaN       NaN
#        1972-12-31                     0.004241     NaN       NaN
#        1973-01-31                     0.004425     NaN  0.043478
#        1973-02-28                     0.003872     NaN -0.125000
#        1973-03-31                     0.002950     NaN -0.238095
# Permco
# 2    True
# 3    True
# 4    True
# 5    True
# dtype: bool

# %%
# Build a visualizer

def simple_plot(dataframe, variable, plot_title):
    plot = TimePlot(title = plot_title, legendLayout=LegendLayout.HORIZONTAL,\
                          legendPosition=LegendPosition(position=LegendPosition.Position.RIGHT),\
                        logY = True,
                        yLogBase = np.exp(1))
    plot.add(Line(displayName = variable, \
                  x = dataframe['datadate'],\
                  y = dataframe[variable]))
    return plot

def price_and_market_cap(dataframe, permco, company_name):
    
    target_view = dataframe[dataframe['Permco'] == permco]
    
    cplot = CombinedPlot(xLabel = 'Date', initWidth = 600, initHeight = 1000)
    cplot.add(simple_plot(target_view, 'Price', 'Price of ' + company_name), 6)
    cplot.add(simple_plot(target_view, 'Market Cap (Billions, CRSP)', 'Market Cap'), 6)
    cplot.add(simple_plot(target_view, 'Volume', 'Volume'), 6)
    
    return cplot

# %%
def find_permcos(dataframe, ticker):
    right_ticker = dataframe.loc[dataframe['Ticker'] == ticker]
    return right_ticker.groupby(by = ['Permco']).first()

# %%
find_permcos(crsp_merge, 'AMZN')

# %%
price_and_market_cap(crsp_merge, 15473, 'Amazon')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Permco'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-647bf2edc96f> in <module>
# ----> 1 price_and_market_cap(crsp_merge, 15473, 'Amazon')
#
# <ipython-input-36-d3699c7ddc8e> in price_and_market_cap(dataframe, permco, company_name)
#      13 def price_and_market_cap(dataframe, permco, company_name):
#      14
# ---> 15     target_view = dataframe[dataframe['Permco'] == permco]
#      16
#      17     cplot = CombinedPlot(xLabel = 'Date', initWidth = 600, initHeight = 1000)
#
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/compustat-crsp/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Permco'

# %%
# Output the data
store = pd.HDFStore('Output/data.h5')
store.put('crsp_only', crsp_merge)

# %% [markdown]
# ## Cleaning up Compustat

# %%
# Define the data types
compustat_datatypes = {'date_vars': ['datadate'],
                 'float_vars': ['cogsq', 'cshopq', 'cshoq', 'dpq', 'oiadpq', 'oibdpq', 'prcraq', 'saleq', 'txpq', 'xintq', 'xsgaq', 'aqcy', 'capxy', 'dvy', 'fincfy', 'oancfy', 'prccq', 'seqq', 'ceqq', 'pstkrq', 'atq', 'ltq', 'cheq'],
                 'int_vars': ['GVKEY', 'LPERMNO', 'LPERMCO', 'fyearq', 'fqtr', 'cusip', 'exchg', 'cik', 'naics']}
compustat = clean_data(copy(compustat_raw), compustat_datatypes)
# Out:
# Cleaning date variables:
# datadate
# Cleaning numeric variables:
# cogsq
# cshopq
# cshoq
# dpq
# oiadpq
# oibdpq
# prcraq
# saleq
# txpq
# xintq
# xsgaq
# aqcy
# capxy
# dvy
# fincfy
# oancfy
# prccq
# seqq
# ceqq
# pstkrq
# atq
# ltq
# cheq
# Cleaning integer variables:
# GVKEY
# LPERMNO
# LPERMCO
# fyearq
# fqtr
# cusip
# exchg
# cik
# naics
# Final data types:
# GVKEY                int16
# LPERMNO              int32
# LPERMCO              int32
# datadate    datetime64[ns]
# fyearq               int16
# fqtr                  int8
# indfmt              object
# consol              object
# popsrc              object
# datafmt             object
# tic                 object
# cusip              float64
# conm                object
# curcdq              object
# datacqtr            object
# datafqtr            object
# rdq                 object
# atq                float64
# ceqq               float64
# cheq               float64
# cogsq              float64
# cshfdq             float64
# cshiq              float64
# cshopq             float64
# cshoq              float64
# dlcq               float64
# dlttq              float64
# dpq                float64
# epsfiq             float64
# epsfxq             float64
# ltq                float64
# niq                float64
# oiadpq             float64
# oibdpq             float64
# prcraq             float64
# pstkrq             float64
# saleq              float64
# seqq               float64
# txditcq            float64
# txpq               float64
# xintq              float64
# xsgaq              float64
# aqcy               float64
# capxy              float64
# dltisy             float64
# dltry              float64
# dvy                float64
# fincfy             float64
# oancfy             float64
# exchg                 int8
# cik                float64
# costat              object
# prccq              float64
# naics              float64
# dtype: object

# %%
compustat_names = \
    {# Identifiers
     'GVKEY': 'Gvkey',
     'LPERMNO': 'Permno',
     'LPERMCO': 'Permco',
     'fyearq': 'Fiscal Year',
     'fqtr': 'Fiscal Quarter',
     'conm': 'Company Name',
     'curcdq': 'Currency',
     'rdq': 'Report Date',     
     'naics': 'NAICS Sector Code',
     'exchg': 'Exchange Code',
     'datadate': 'datadate',
     
     # Balance Sheet
     'atq': 'Assets, Total',
     'ceqq': 'Common Equity, Total',
     'seqq': 'Shareholder Equity, Total',
     'pstkrq': 'Preferred Equity, Total',
     'ltq': 'Liabilities, Total',
     'txditcq': 'Deferred Tax Assets',
     'dlttq': 'Long Term Debt',
     'dlcq': 'Short Term Debt',
     'cheq': 'Cash',
        
     # Income Statement
     'saleq': 'Sales',
     'cogsq': 'COGS',
     'xsgaq': 'SG&A',
     'dpq': 'Depreciation and Amortization',
     'oibdpq': 'EBITDA',
     'oiadpq': 'EBIT',
     'xintq': 'Interest Expense',
     'txpq': 'Taxes Payable',
     'niq': 'Net Income',
     'epsfiq': 'Diluted EPS, Raw',
     'epsfxq': 'Diluted EPS, Adjusted',
     
     # Cash Flow Statement
     'oancfy': 'Operating Cash Flow',
     'fincfy': 'Financing Activities',
     'dltisy': 'Long Term Debt, Gross Issuance',
     'dltry': 'Long Term Debt, Retired',
     'dvy': 'Cash Dividends',
     'capxy': 'Capex',
     'aqcy': 'M&A',
     'cshopq': 'Total Repurchased Shares',
     'prcraq': 'Repurchase Price',
        
     # Market Data
     'cshoq': 'Shares Outstanding (Compustat)',
     'prccq': 'Price (Compustat)',
     'cshfdq': 'Shares Outstanding for EPS'}
compustat = compustat.rename(index = str, columns = compustat_names)
compustat = compustat[list(compustat_names.values())]

# %%
compustat = compustat.set_index(['Gvkey', 'datadate', 'Fiscal Year'])

# %%
# Convert the yearly variables
yearly_variables = sorted([compustat_names[x] for x in list(compustat_names.keys()) if x[-1] == 'y'])

# %%
def take_diffs(x):
    
    if x.name[1] == 2000:
        print(x.name)
        
    if all(np.isnan(x)):
        return x
    
    x = x.fillna(0)
    ret = x.diff()
    ret[0] = x[0]
    return ret


apple = compustat.xs(1166, level = 'Gvkey', drop_level = False)
orchard = apple.groupby(by = ['Gvkey', 'Fiscal Year'])

for v in yearly_variables:
    print(orchard[v].transform(take_diffs))
# Out:
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981              NaN
#        1981-09-30  1981              NaN
#        1981-12-31  1981              NaN
#        1982-03-31  1982              NaN
#        1982-06-30  1982              NaN
#        1982-09-30  1982              NaN
#        1982-12-31  1982              NaN
#        1983-03-31  1983              NaN
#        1983-06-30  1983              NaN
#        1983-09-30  1983              NaN
#        1983-12-31  1983              NaN
#        1984-03-31  1984            0.000
#        1984-06-30  1984            0.000
#        1984-09-30  1984            0.000
#        1984-12-31  1984           14.363
#        1985-03-31  1985            0.000
#        1985-06-30  1985            0.000
#        1985-09-30  1985            0.000
#        1985-12-31  1985           15.990
#        1986-03-31  1986            0.000
#        1986-06-30  1986            0.000
#        1986-09-30  1986            0.000
#        1986-12-31  1986            8.907
#        1987-03-31  1987            0.000
#        1987-06-30  1987            0.000
#        1987-09-30  1987            0.000
#        1987-12-31  1987            7.993
#        1988-03-31  1988            0.000
#        1988-06-30  1988            0.000
#        1988-09-30  1988            0.000
#                                    ...
#        2008-03-31  2008           15.434
#        2008-06-30  2008           10.734
#        2008-09-30  2008            8.178
#        2008-12-31  2008            9.430
#        2009-03-31  2009            2.302
#        2009-06-30  2009            1.352
#        2009-09-30  2009            3.166
#        2009-12-31  2009           11.408
#        2010-03-31  2010           15.114
#        2010-06-30  2010           22.188
#        2010-09-30  2010           49.267
#        2010-12-31  2010           50.067
#        2011-03-31  2011           30.547
#        2011-06-30  2011           38.728
#        2011-09-30  2011           24.398
#        2011-12-31  2011           22.069
#        2012-03-31  2012           22.965
#        2012-06-30  2012           20.627
#        2012-09-30  2012           18.767
#        2012-12-31  2012           27.519
#        2013-03-31  2013            8.635
#        2013-06-30  2013            0.399
#        2013-09-30  2013            3.107
#        2013-12-31  2013           11.370
#        2014-03-31  2014            5.685
#        2014-06-30  2014            8.796
#        2014-09-30  2014           11.182
#        2014-12-31  2014           11.423
#        2015-03-31  2015            8.297
#        2015-06-30  2015           10.446
# Name: Capex, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981               NaN
#        1981-09-30  1981               NaN
#        1981-12-31  1981               NaN
#        1982-03-31  1982               NaN
#        1982-06-30  1982               NaN
#        1982-09-30  1982               NaN
#        1982-12-31  1982               NaN
#        1983-03-31  1983               NaN
#        1983-06-30  1983               NaN
#        1983-09-30  1983               NaN
#        1983-12-31  1983               NaN
#        1984-03-31  1984             0.000
#        1984-06-30  1984             0.000
#        1984-09-30  1984             0.000
#        1984-12-31  1984             0.000
#        1985-03-31  1985             0.000
#        1985-06-30  1985             0.000
#        1985-09-30  1985             0.000
#        1985-12-31  1985             0.000
#        1986-03-31  1986             0.000
#        1986-06-30  1986             0.000
#        1986-09-30  1986             0.000
#        1986-12-31  1986             0.000
#        1987-03-31  1987             0.000
#        1987-06-30  1987             0.000
#        1987-09-30  1987             0.000
#        1987-12-31  1987             0.000
#        1988-03-31  1988             0.000
#        1988-06-30  1988             0.000
#        1988-09-30  1988             0.000
#                                    ...
#        2008-03-31  2008             0.000
#        2008-06-30  2008             0.000
#        2008-09-30  2008             0.000
#        2008-12-31  2008             0.000
#        2009-03-31  2009             0.000
#        2009-06-30  2009             0.000
#        2009-09-30  2009             0.000
#        2009-12-31  2009             0.000
#        2010-03-31  2010             0.000
#        2010-06-30  2010             0.000
#        2010-09-30  2010             0.000
#        2010-12-31  2010             0.000
#        2011-03-31  2011             0.000
#        2011-06-30  2011            32.116
#        2011-09-30  2011            -2.374
#        2011-12-31  2011            -0.862
#        2012-03-31  2012             0.000
#        2012-06-30  2012            34.737
#        2012-09-30  2012             0.641
#        2012-12-31  2012             0.909
#        2013-03-31  2013             0.000
#        2013-06-30  2013            41.217
#        2013-09-30  2013           366.657
#        2013-12-31  2013             7.161
#        2014-03-31  2014             0.000
#        2014-06-30  2014            37.922
#        2014-09-30  2014             2.270
#        2014-12-31  2014            -1.677
#        2015-03-31  2015             0.000
#        2015-06-30  2015            36.223
# Name: Cash Dividends, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981               NaN
#        1981-09-30  1981               NaN
#        1981-12-31  1981               NaN
#        1982-03-31  1982               NaN
#        1982-06-30  1982               NaN
#        1982-09-30  1982               NaN
#        1982-12-31  1982               NaN
#        1983-03-31  1983               NaN
#        1983-06-30  1983               NaN
#        1983-09-30  1983               NaN
#        1983-12-31  1983               NaN
#        1984-03-31  1984               NaN
#        1984-06-30  1984               NaN
#        1984-09-30  1984               NaN
#        1984-12-31  1984               NaN
#        1985-03-31  1985               NaN
#        1985-06-30  1985               NaN
#        1985-09-30  1985               NaN
#        1985-12-31  1985               NaN
#        1986-03-31  1986               NaN
#        1986-06-30  1986               NaN
#        1986-09-30  1986               NaN
#        1986-12-31  1986               NaN
#        1987-03-31  1987               NaN
#        1987-06-30  1987               NaN
#        1987-09-30  1987               NaN
#        1987-12-31  1987               NaN
#        1988-03-31  1988             0.000
#        1988-06-30  1988             0.000
#        1988-09-30  1988             0.000
#                                    ...
#        2008-03-31  2008            -4.029
#        2008-06-30  2008           -85.850
#        2008-09-30  2008           -28.207
#        2008-12-31  2008           -51.083
#        2009-03-31  2009            -3.006
#        2009-06-30  2009           -21.690
#        2009-09-30  2009           -18.721
#        2009-12-31  2009           173.681
#        2010-03-31  2010           -54.373
#        2010-06-30  2010           -32.460
#        2010-09-30  2010           -66.434
#        2010-12-31  2010            -9.978
#        2011-03-31  2011           108.808
#        2011-06-30  2011          -130.150
#        2011-09-30  2011           -69.487
#        2011-12-31  2011           -11.057
#        2012-03-31  2012            -7.704
#        2012-06-30  2012           -34.275
#        2012-09-30  2012            -7.369
#        2012-12-31  2012           -47.555
#        2013-03-31  2013           -28.251
#        2013-06-30  2013           -33.984
#        2013-09-30  2013          -359.708
#        2013-12-31  2013            -1.217
#        2014-03-31  2014             0.989
#        2014-06-30  2014           -26.617
#        2014-09-30  2014            12.715
#        2014-12-31  2014           -32.889
#        2015-03-31  2015           -26.289
#        2015-06-30  2015           -49.649
# Name: Financing Activities, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981               NaN
#        1981-09-30  1981               NaN
#        1981-12-31  1981               NaN
#        1982-03-31  1982               NaN
#        1982-06-30  1982               NaN
#        1982-09-30  1982               NaN
#        1982-12-31  1982               NaN
#        1983-03-31  1983               NaN
#        1983-06-30  1983               NaN
#        1983-09-30  1983               NaN
#        1983-12-31  1983               NaN
#        1984-03-31  1984             0.000
#        1984-06-30  1984             0.000
#        1984-09-30  1984             0.000
#        1984-12-31  1984             0.868
#        1985-03-31  1985             0.000
#        1985-06-30  1985             0.000
#        1985-09-30  1985             0.000
#        1985-12-31  1985            14.645
#        1986-03-31  1986             0.000
#        1986-06-30  1986             0.000
#        1986-09-30  1986             0.000
#        1986-12-31  1986            22.453
#        1987-03-31  1987             0.000
#        1987-06-30  1987             0.000
#        1987-09-30  1987             0.000
#        1987-12-31  1987            20.435
#        1988-03-31  1988             0.000
#        1988-06-30  1988             0.000
#        1988-09-30  1988             0.000
#                                    ...
#        2008-03-31  2008             0.000
#        2008-06-30  2008             0.000
#        2008-09-30  2008             0.000
#        2008-12-31  2008            11.107
#        2009-03-31  2009             0.000
#        2009-06-30  2009             0.000
#        2009-09-30  2009             0.000
#        2009-12-31  2009           207.121
#        2010-03-31  2010             0.000
#        2010-06-30  2010             0.000
#        2010-09-30  2010             0.000
#        2010-12-31  2010             0.000
#        2011-03-31  2011             0.000
#        2011-06-30  2011             0.000
#        2011-09-30  2011             0.000
#        2011-12-31  2011            54.711
#        2012-03-31  2012             0.000
#        2012-06-30  2012             0.000
#        2012-09-30  2012             0.000
#        2012-12-31  2012            62.867
#        2013-03-31  2013            24.325
#        2013-06-30  2013             0.368
#        2013-09-30  2013             0.996
#        2013-12-31  2013             0.464
#        2014-03-31  2014             0.000
#        2014-06-30  2014             0.000
#        2014-09-30  2014             0.000
#        2014-12-31  2014             0.000
#        2015-03-31  2015             0.000
#        2015-06-30  2015             0.000
# Name: Long Term Debt, Gross Issuance, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981              NaN
#        1981-09-30  1981              NaN
#        1981-12-31  1981              NaN
#        1982-03-31  1982              NaN
#        1982-06-30  1982              NaN
#        1982-09-30  1982              NaN
#        1982-12-31  1982              NaN
#        1983-03-31  1983              NaN
#        1983-06-30  1983              NaN
#        1983-09-30  1983              NaN
#        1983-12-31  1983              NaN
#        1984-03-31  1984            0.000
#        1984-06-30  1984            0.000
#        1984-09-30  1984            0.000
#        1984-12-31  1984            0.839
#        1985-03-31  1985            0.000
#        1985-06-30  1985            0.000
#        1985-09-30  1985            0.000
#        1985-12-31  1985            1.126
#        1986-03-31  1986            0.000
#        1986-06-30  1986            0.000
#        1986-09-30  1986            0.000
#        1986-12-31  1986            1.886
#        1987-03-31  1987            0.000
#        1987-06-30  1987            0.000
#        1987-09-30  1987            0.000
#        1987-12-31  1987            2.359
#        1988-03-31  1988            0.000
#        1988-06-30  1988            0.000
#        1988-09-30  1988            0.000
#                                    ...
#        2008-03-31  2008            2.733
#        2008-06-30  2008            4.184
#        2008-09-30  2008           12.021
#        2008-12-31  2008           44.746
#        2009-03-31  2009            3.006
#        2009-06-30  2009            2.200
#        2009-09-30  2009            2.767
#        2009-12-31  2009           38.242
#        2010-03-31  2010           49.554
#        2010-06-30  2010           -2.550
#        2010-09-30  2010           16.707
#        2010-12-31  2010           13.240
#        2011-03-31  2011            3.249
#        2011-06-30  2011            1.488
#        2011-09-30  2011            3.492
#        2011-12-31  2011           21.733
#        2012-03-31  2012            2.371
#        2012-06-30  2012            0.382
#        2012-09-30  2012           15.413
#        2012-12-31  2012           14.438
#        2013-03-31  2013            1.971
#        2013-06-30  2013            0.030
#        2013-09-30  2013            0.081
#        2013-12-31  2013           54.259
#        2014-03-31  2014            0.000
#        2014-06-30  2014            0.000
#        2014-09-30  2014            0.000
#        2014-12-31  2014            0.000
#        2015-03-31  2015            0.000
#        2015-06-30  2015            0.000
# Name: Long Term Debt, Retired, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981              NaN
#        1981-09-30  1981              NaN
#        1981-12-31  1981              NaN
#        1982-03-31  1982              NaN
#        1982-06-30  1982              NaN
#        1982-09-30  1982              NaN
#        1982-12-31  1982              NaN
#        1983-03-31  1983              NaN
#        1983-06-30  1983              NaN
#        1983-09-30  1983              NaN
#        1983-12-31  1983              NaN
#        1984-03-31  1984            0.000
#        1984-06-30  1984            0.000
#        1984-09-30  1984            0.000
#        1984-12-31  1984            0.000
#        1985-03-31  1985            0.000
#        1985-06-30  1985            0.000
#        1985-09-30  1985            0.000
#        1985-12-31  1985            0.000
#        1986-03-31  1986            0.000
#        1986-06-30  1986            0.000
#        1986-09-30  1986            0.000
#        1986-12-31  1986            0.000
#        1987-03-31  1987            0.000
#        1987-06-30  1987            0.000
#        1987-09-30  1987            0.000
#        1987-12-31  1987            0.000
#        1988-03-31  1988            0.000
#        1988-06-30  1988            0.000
#        1988-09-30  1988            0.000
#                                    ...
#        2008-03-31  2008            0.000
#        2008-06-30  2008            0.000
#        2008-09-30  2008            0.000
#        2008-12-31  2008            0.245
#        2009-03-31  2009            0.000
#        2009-06-30  2009            0.000
#        2009-09-30  2009            0.000
#        2009-12-31  2009            0.072
#        2010-03-31  2010            0.000
#        2010-06-30  2010            0.000
#        2010-09-30  2010            0.000
#        2010-12-31  2010            0.000
#        2011-03-31  2011            1.410
#        2011-06-30  2011            0.034
#        2011-09-30  2011           -0.107
#        2011-12-31  2011          -56.394
#        2012-03-31  2012            0.000
#        2012-06-30  2012            0.000
#        2012-09-30  2012            0.000
#        2012-12-31  2012            0.000
#        2013-03-31  2013            0.000
#        2013-06-30  2013            0.000
#        2013-09-30  2013            0.000
#        2013-12-31  2013            0.000
#        2014-03-31  2014            0.000
#        2014-06-30  2014            0.000
#        2014-09-30  2014            0.000
#        2014-12-31  2014            0.000
#        2015-03-31  2015            0.000
#        2015-06-30  2015            0.000
# Name: M&A, Length: 137, dtype: float64
# (1166, 2000)
# Gvkey  datadate    Fiscal Year
# 1166   1981-06-30  1981               NaN
#        1981-09-30  1981               NaN
#        1981-12-31  1981               NaN
#        1982-03-31  1982               NaN
#        1982-06-30  1982               NaN
#        1982-09-30  1982               NaN
#        1982-12-31  1982               NaN
#        1983-03-31  1983               NaN
#        1983-06-30  1983               NaN
#        1983-09-30  1983               NaN
#        1983-12-31  1983               NaN
#        1984-03-31  1984               NaN
#        1984-06-30  1984               NaN
#        1984-09-30  1984               NaN
#        1984-12-31  1984               NaN
#        1985-03-31  1985               NaN
#        1985-06-30  1985               NaN
#        1985-09-30  1985               NaN
#        1985-12-31  1985               NaN
#        1986-03-31  1986               NaN
#        1986-06-30  1986               NaN
#        1986-09-30  1986               NaN
#        1986-12-31  1986               NaN
#        1987-03-31  1987               NaN
#        1987-06-30  1987               NaN
#        1987-09-30  1987               NaN
#        1987-12-31  1987               NaN
#        1988-03-31  1988             0.000
#        1988-06-30  1988             0.000
#        1988-09-30  1988             0.000
#                                    ...
#        2008-03-31  2008            50.427
#        2008-06-30  2008            46.338
#        2008-09-30  2008            56.973
#        2008-12-31  2008            37.512
#        2009-03-31  2009             7.902
#        2009-06-30  2009            -8.583
#        2009-09-30  2009            46.742
#        2009-12-31  2009            43.732
#        2010-03-31  2010            34.871
#        2010-06-30  2010            72.074
#        2010-09-30  2010           147.781
#        2010-12-31  2010            90.114
#        2011-03-31  2011           119.181
#        2011-06-30  2011            44.271
#        2011-09-30  2011            74.098
#        2011-12-31  2011            43.420
#        2012-03-31  2012            51.345
#        2012-06-30  2012           -34.856
#        2012-09-30  2012           -26.266
#        2012-12-31  2012            65.791
#        2013-03-31  2013             2.143
#        2013-06-30  2013             0.658
#        2013-09-30  2013            46.637
#        2013-12-31  2013            17.452
#        2014-03-31  2014            86.183
#        2014-06-30  2014            24.542
#        2014-09-30  2014            19.703
#        2014-12-31  2014             3.155
#        2015-03-31  2015            39.020
#        2015-06-30  2015            13.921
# Name: Operating Cash Flow, Length: 137, dtype: float64

# %%
cashflow_groups = compustat[yearly_variables].groupby(['Gvkey', 'Fiscal Year'])

# %%
from multiprocessing import Pool
import time

p = Pool(4)

def cash_flow(variable):
    print(variable)
    return cashflow_groups[variable].transform(take_diffs)

# %%
with Pool(4) as p:
    new_dataframes = p.map(cash_flow, yearly_variables)
# Out:
# Cash Dividends
# Financing Activities
# Long Term Debt, Gross Issuance
# Capex
# (1004, 2000)
# (1004, 2000)
# (1004, 2000)
# (1004, 2000)
# (1013, 2000)
# (1013, 2000)
# (1013, 2000)
# (1013, 2000)
# (1034, 2000)
# (1036, 2000)
# (1034, 2000)
# (1034, 2000)
# (1034, 2000)
# (1038, 2000)
# (1036, 2000)
# (1036, 2000)
# (1036, 2000)
# (1038, 2000)
# (1038, 2000)
# (1038, 2000)
# (1043, 2000)
# (1045, 2000)
# (1043, 2000)
# (1043, 2000)
# (1043, 2000)
# (1045, 2000)
# (1050, 2000)
# (1045, 2000)
# (1045, 2000)
# (1050, 2000)
# (1050, 2000)
# (1050, 2000)
# (1056, 2000)
# (1062, 2000)
# (1056, 2000)
# (1056, 2000)
# (1056, 2000)
# (1072, 2000)
# (1062, 2000)
# (1062, 2000)
# (1062, 2000)
# (1075, 2000)
# (1072, 2000)
# (1072, 2000)
# (1072, 2000)
# (1076, 2000)
# (1075, 2000)
# (1075, 2000)
# (1075, 2000)
# (1078, 2000)
# (1076, 2000)
# (1076, 2000)
# (1076, 2000)
# (1081, 2000)
# (1082, 2000)
# (1078, 2000)
# (1078, 2000)
# (1078, 2000)
# (1094, 2000)
# (1081, 2000)
# (1081, 2000)
# (1081, 2000)
# (1082, 2000)
# (1095, 2000)
# (1082, 2000)
# (1082, 2000)
# (1097, 2000)
# (1094, 2000)
# (1094, 2000)
# (1094, 2000)
# (1099, 2000)
# (1095, 2000)
# (1095, 2000)
# (1095, 2000)
# (1104, 2000)
# (1097, 2000)
# (1097, 2000)
# (1097, 2000)
# (1099, 2000)
# (1109, 2000)
# (1099, 2000)
# (1099, 2000)
# (1111, 2000)
# (1104, 2000)
# (1104, 2000)
# (1104, 2000)
# (1115, 2000)
# (1117, 2000)
# (1109, 2000)
# (1109, 2000)
# (1109, 2000)
# (1119, 2000)
# (1111, 2000)
# (1111, 2000)
# (1111, 2000)
# (1121, 2000)
# (1115, 2000)
# (1115, 2000)
# (1115, 2000)
# (1117, 2000)
# (1117, 2000)
# (1117, 2000)
# (1119, 2000)
# (1119, 2000)
# (1119, 2000)
# (1121, 2000)
# (1121, 2000)
# (1121, 2000)
# (1148, 2000)
# (1154, 2000)
# (1161, 2000)
# (1164, 2000)
# (1148, 2000)
# (1148, 2000)
# (1148, 2000)
# (1166, 2000)
# (1154, 2000)
# (1154, 2000)
# (1154, 2000)
# (1173, 2000)
# (1161, 2000)
# (1161, 2000)
# (1161, 2000)
# (1164, 2000)
# (1164, 2000)
# (1164, 2000)
# (1166, 2000)
# (1177, 2000)
# (1166, 2000)
# (1166, 2000)
# (1186, 2000)
# (1173, 2000)
# (1173, 2000)
# (1173, 2000)
# (1177, 2000)
# (1177, 2000)
# (1177, 2000)
# (1209, 2000)
# (1186, 2000)
# (1210, 2000)
# (1186, 2000)
# (1186, 2000)
# (1213, 2000)
# (1228, 2000)
# (1209, 2000)
# (1230, 2000)
# (1209, 2000)
# (1209, 2000)
# (1210, 2000)
# (1210, 2000)
# (1210, 2000)
# (1213, 2000)
# Long Term Debt, Retired
# (1213, 2000)
# (1213, 2000)
# (1004, 2000)
# (1228, 2000)
# (1228, 2000)
# (1228, 2000)
# (1230, 2000)
# (1230, 2000)
# (1013, 2000)
# (1230, 2000)
# M&A
# Operating Cash Flow
# (1004, 2000)
# (1034, 2000)
# (1004, 2000)
# (1036, 2000)
# (1038, 2000)
# (1013, 2000)
# (1013, 2000)
# (1043, 2000)
# (1045, 2000)
# (1034, 2000)
# (1050, 2000)
# (1034, 2000)
# (1036, 2000)
# (1036, 2000)
# (1038, 2000)
# (1056, 2000)
# (1038, 2000)
# (1043, 2000)
# (1062, 2000)
# (1045, 2000)
# (1043, 2000)
# (1045, 2000)
# (1050, 2000)
# (1072, 2000)
# (1050, 2000)
# (1056, 2000)
# (1075, 2000)
# (1076, 2000)
# (1056, 2000)
# (1062, 2000)
# (1078, 2000)
# (1062, 2000)
# (1072, 2000)
# (1081, 2000)
# (1082, 2000)
# (1072, 2000)
# (1075, 2000)
# (1076, 2000)
# (1094, 2000)
# (1075, 2000)
# (1095, 2000)
# (1078, 2000)
# (1076, 2000)
# (1097, 2000)
# (1081, 2000)
# (1082, 2000)
# (1078, 2000)
# (1099, 2000)
# (1081, 2000)
# (1094, 2000)
# (1104, 2000)
# (1082, 2000)
# (1095, 2000)
# (1097, 2000)
# (1109, 2000)
# (1094, 2000)
# (1111, 2000)
# (1099, 2000)
# (1095, 2000)
# (1104, 2000)
# (1097, 2000)
# (1115, 2000)
# (1117, 2000)
# (1099, 2000)
# (1109, 2000)
# (1119, 2000)
# (1111, 2000)
# (1104, 2000)
# (1121, 2000)
# (1115, 2000)
# (1109, 2000)
# (1117, 2000)
# (1111, 2000)
# (1119, 2000)
# (1115, 2000)
# (1121, 2000)
# (1117, 2000)
# (1148, 2000)
# (1119, 2000)
# (1121, 2000)
# (1154, 2000)
# (1148, 2000)
# (1161, 2000)
# (1154, 2000)
# (1164, 2000)
# (1161, 2000)
# (1166, 2000)
# (1148, 2000)
# (1164, 2000)
# (1173, 2000)
# (1166, 2000)
# (1154, 2000)
# (1177, 2000)
# (1173, 2000)
# (1161, 2000)
# (1177, 2000)
# (1164, 2000)
# (1186, 2000)
# (1186, 2000)
# (1166, 2000)
# (1173, 2000)
# (1177, 2000)
# (1209, 2000)
# (1209, 2000)
# (1210, 2000)
# (1210, 2000)
# (1186, 2000)
# (1213, 2000)
# (1213, 2000)
# (1228, 2000)
# (1228, 2000)
# (1209, 2000)
# (1230, 2000)
# (1230, 2000)
# (1210, 2000)
# (1213, 2000)
# (1228, 2000)
# (1230, 2000)

# %%
for d in new_dataframes:
    compustat[d.name] = d

# %%
compustat.head()

# %%
# Make some variables
compustat['Market Cap (Compustat)'] = compustat['Price (Compustat)'] * compustat['Shares Outstanding (Compustat)'] / 1e3

# %%
compustat.columns
# Out:
# Index(['Permno', 'Permco', 'Fiscal Quarter', 'Company Name', 'Currency',
#        'Report Date', 'NAICS Sector Code', 'Exchange Code', 'Assets, Total',
#        'Common Equity, Total', 'Shareholder Equity, Total',
#        'Preferred Equity, Total', 'Liabilities, Total', 'Deferred Tax Assets',
#        'Long Term Debt', 'Short Term Debt', 'Cash', 'Sales', 'COGS', 'SG&A',
#        'Depreciation and Amortization', 'EBITDA', 'EBIT', 'Interest Expense',
#        'Taxes Payable', 'Net Income', 'Diluted EPS, Raw',
#        'Diluted EPS, Adjusted', 'Operating Cash Flow', 'Financing Activities',
#        'Long Term Debt, Gross Issuance', 'Long Term Debt, Retired',
#        'Cash Dividends', 'Capex', 'M&A', 'Total Repurchased Shares',
#        'Repurchase Price', 'Shares Outstanding (Compustat)',
#        'Price (Compustat)', 'Shares Outstanding for EPS',
#        'Market Cap (Compustat)'],
#       dtype='object')

# %%
compustat = compustat.reset_index().set_index(['Permco', 'datadate'])
x = compustat.xs(47, level = 'Permco', drop_level = False).xs('1988-03-31', level = 'datadate', drop_level = False)

# %%
x.apply(pd.Series.nunique, axis = 0)
# Out:
# Gvkey                             1
# Fiscal Year                       1
# Permno                            2
# Fiscal Quarter                    1
# Company Name                      1
# Currency                          1
# Report Date                       1
# NAICS Sector Code                 1
# Exchange Code                     1
# Assets, Total                     1
# Common Equity, Total              1
# Shareholder Equity, Total         1
# Preferred Equity, Total           1
# Liabilities, Total                1
# Deferred Tax Assets               1
# Long Term Debt                    1
# Short Term Debt                   1
# Cash                              1
# Sales                             1
# COGS                              1
# SG&A                              1
# Depreciation and Amortization     1
# EBITDA                            1
# EBIT                              1
# Interest Expense                  1
# Taxes Payable                     1
# Net Income                        1
# Diluted EPS, Raw                  1
# Diluted EPS, Adjusted             1
# Operating Cash Flow               1
# Financing Activities              1
# Long Term Debt, Gross Issuance    1
# Long Term Debt, Retired           1
# Cash Dividends                    1
# Capex                             2
# M&A                               1
# Total Repurchased Shares          0
# Repurchase Price                  0
# Shares Outstanding (Compustat)    1
# Price (Compustat)                 1
# Shares Outstanding for EPS        0
# Market Cap (Compustat)            1
# dtype: int64

# %%
x

# %%
compustat.xs(47, level = 'Permco', drop_level = False).xs('1988-03-31', level = 'datadate', drop_level = False)

# %%
store.put('compustat_only', compustat)

# %% [markdown]
# ## Combine the two dataframes

# %%
compustat = compustat.reset_index().set_index(['Permco', 'datadate'])
crsp = crsp.reset_index().set_index(['Permco', 'datadate'])

# %%
merged_datasets = crsp.join(compustat, how = 'left', lsuffix = '.crsp', rsuffix = '.comp')

# %%
compustat.xs(7, level = 'Permco', drop_level = False)

# %%
crsp.loc[crsp['Company Name'] == 'APPLE INC']

# %%
merged_datasets.shape

# %%
crsp.shape

# %%
crsp.xs(540, level = 'Permco')

# %%
merged_datasets.xs(7, level = 'Permco')
